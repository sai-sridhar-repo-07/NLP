# %%
corpus = '''Hari is great!
Hari is pretty.
Hari is beautiful'''

# %%
corpus
# Out:
# 'Hari is great!\nHari is pretty.\nHari is beautiful'

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk

# Force download to the NLTK directory that Jupyter actually uses
nltk.download('punkt', download_dir='c:/Users/dell/AppData/Roaming/nltk_data')
nltk.download('punkt_tab', download_dir='c:/Users/dell/AppData/Roaming/nltk_data')

# Tell NLTK to look there
nltk.data.path.append('c:/Users/dell/AppData/Roaming/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     c:/Users/dell/AppData/Roaming/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     c:/Users/dell/AppData/Roaming/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(corpus)
sentences
# Out:
# ['Hari is great!', 'Hari is pretty.', 'Hari is beautiful']

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(corpus)
words
# Out:
# ['Hari',
#  'is',
#  'great',
#  '!',
#  'Hari',
#  'is',
#  'pretty',
#  '.',
#  'Hari',
#  'is',
#  'beautiful']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Hari',
#  'is',
#  'great',
#  '!',
#  'Hari',
#  'is',
#  'pretty',
#  '.',
#  'Hari',
#  'is',
#  'beautiful']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hari',
#  'is',
#  'great',
#  '!',
#  'Hari',
#  'is',
#  'pretty.',
#  'Hari',
#  'is',
#  'beautiful']
